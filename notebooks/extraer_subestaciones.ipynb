# %%
import pandas as pd
from pathlib import Path

# Leer archivo
ruta = Path("../data/SUBESTACIONES/subestacion_con_coordenadas.csv")
df = pd.read_csv(ruta, usecols=[0])

# Mostrar la columna
print(df["Subestacion"])

ruta_salida = Path("../data/lista_subestaciones_limpia.csv")

df.to_csv(ruta_salida, index=False)
# Out:
# 0        Arboleda
# 1        Arocagua
# 2         Bermejo
# 3         Brechas
# 4     Brechas 115
#          ...
# 56      Vinto 115
# 57         Warnes
# 58        Yacuiba
# 59       Yapacani
# 60         Yucumo
# Name: Subestacion, Length: 61, dtype: object
